# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_column', 40)

# %%
df=pd.read_csv('student-por.csv')

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.school.unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
df.school.value_counts()
# Out:
# school
# GP    423
# MS    226
# Name: count, dtype: int64

# %%
df.sex.value_counts(normalize=True)    #insights- 59% students are female and 41% are male.
# Out:
# sex
# F    0.590139
# M    0.409861
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='school', palette='viridis', hue='sex')
plt.title('No. of students in each school')
plt.show()

# %%
df.age             #continuous data
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
#        ..
# 644    19
# 645    18
# 646    18
# 647    17
# 648    18
# Name: age, Length: 649, dtype: int64

# %%
sns.histplot(data=df, x='age', kde=True, hue='school')
plt.show()

# insights - majority students have age between 15 to 18.

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.address.unique()
# Out:
# array(['U', 'R'], dtype=object)

# %%
sns.countplot(data=df, x=df.address, hue='sex')
plt.show()

# insights - large no. of students are from urban areas.

# %%
df.reason.unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
df.reason.value_counts()
# Out:
# reason
# course        285
# home          149
# reputation    143
# other          72
# Name: count, dtype: int64

# %%
df.reason.value_counts().plot.pie(autopct='%1.1f%%',colors = ['#add8e6', '#87ceeb', '#b0e0e6', '#98fb98'])
plt.show()

# %%
df.traveltime.unique()
# Out:
# array([2, 1, 3, 4], dtype=int64)

# %%
df.studytime.unique()
# Out:
# array([2, 3, 1, 4], dtype=int64)

# %%
cross_tab = pd.crosstab(df['studytime'], df['traveltime'], normalize='index')

# %%
cross_tab
# Out:
# traveltime         1         2         3         4
# studytime
# 1           0.495283  0.372642  0.108491  0.023585
# 2           0.593443  0.301639  0.085246  0.019672
# 3           0.628866  0.309278  0.030928  0.030928
# 4           0.542857  0.342857  0.057143  0.057143

# %%
#this heatmap shows as traveltime increases, student's study time is decreased.
sns.heatmap(data=cross_tab, annot=True, cmap='coolwarm', fmt='.2%')
plt.show()

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
temp = df[['traveltime', 'studytime', 'failures']]

# %%
failures_corr = student_progress.corr()

# %%
failures_corr
# Out:
#             traveltime  studytime  failures
# traveltime    1.000000  -0.063154  0.097730
# studytime    -0.063154   1.000000 -0.147441
# failures      0.097730  -0.147441  1.000000

# %%
_,ax = plt.subplots(figsize=(10,5))
sns.heatmap(data=failures_corr, annot=True,fmt=".2f", ax=ax, linewidths=0.5, linecolor='orange')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.title("correlation between traveltime, studytime and failures.")
plt.show()

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         0       yes     no   no
# 3    home   mother           1          3         0        no    yes   no
# 4    home   father           1          2         0        no    yes   no
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# ...

# %%
df.Walc.value_counts()
# Out:
# Walc
# 1    247
# 2    150
# 3    120
# 4     87
# 5     45
# Name: count, dtype: int64

# %%
df.Dalc.value_counts()
# Out:
# Dalc
# 1    451
# 2    121
# 3     43
# 5     17
# 4     17
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df, x='Dalc', y='failures', palette='viridis', hue='sex')
plt.show()

# insights - most of the failures consume more alcholic.

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df, x='Walc', y='health', palette='viridis', hue='sex')
plt.show()

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
sns.boxplot(data=df, x='Pstatus', y='absences', palette='viridis', hue='sex')
plt.show()

# %%
df.absences.value_counts()
# Out:
# absences
# 0     244
# 2     110
# 4      93
# 6      49
# 8      42
# 10     21
# 1      12
# 12     12
# 5      12
# 16     10
# 14      8
# 9       7
# 3       7
# 11      5
# 18      3
# 7       3
# 21      2
# 15      2
# 22      2
# 30      1
# 26      1
# 24      1
# 13      1
# 32      1
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='health', palette='viridis', hue='sex')
# Out:
# <Axes: xlabel='health', ylabel='count'>

# %%
df.hist(figsize=(30,20), bins=50, color='green')
plt.show()

# %%
plt.figure(figsize=(40,30))
sns.pairplot(data=df)
plt.show()

# %%
df.G1.value_counts()
# Out:
# G1
# 10    95
# 11    91
# 12    82
# 13    72
# 14    71
# 9     65
# 8     42
# 15    35
# 7     33
# 16    22
# 17    16
# 6      9
# 18     7
# 5      5
# 4      2
# 0      1
# 19     1
# Name: count, dtype: int64

# %%
df.G1.describe()
# Out:
# count    649.000000
# mean      11.399076
# std        2.745265
# min        0.000000
# 25%       10.000000
# 50%       11.000000
# 75%       13.000000
# max       19.000000
# Name: G1, dtype: float64

# %%
df.G2.describe()
# Out:
# count    649.000000
# mean      11.570108
# std        2.913639
# min        0.000000
# 25%       10.000000
# 50%       11.000000
# 75%       13.000000
# max       19.000000
# Name: G2, dtype: float64

# %%
df.G3.describe()
# Out:
# count    649.000000
# mean      11.906009
# std        3.230656
# min        0.000000
# 25%       10.000000
# 50%       12.000000
# 75%       14.000000
# max       19.000000
# Name: G3, dtype: float64

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         0       yes     no   no
# 3    home   mother           1          3         0        no    yes   no
# 4    home   father           1          2         0        no    yes   no
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# ...

# %%
# Q.) Do urban students score higher than rural students.?
sns.kdeplot(data=df.loc[df['address']=='U', 'G1'], label='urban', shade=True)
sns.kdeplot(data=df.loc[df['address']=='R', 'G1'], label='Rural', shade=True)
plt.title("G1 comparision of rural and urban student's")
plt.show()
